# %%
# Google Colabでライブラリをアップロードする
from google.colab import files
uploaded = files.upload()

# %%
# Google Colabでドライブのデータを使う
from google.colab import drive
drive.mount('/content/drive')

# %%
# Google Colabでライブラリをインストールする
# !pip install japanize_matplotlib bottleneck tslearn

# %%
# 自作関数
import MasterResearchFunction as mr

# 基本ライブラリ
import os, re, csv, math, statistics
from datetime import datetime, timedelta
from decimal import Decimal
import pickle

# 数値計算とデータ処理
import numpy as np
import pandas as pd
import bottleneck as bn

# 機械学習ライブラリ
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# ディープラーニングライブラリ
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation, Conv1D, MaxPooling1D, Flatten

# プロットと可視化
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import japanize_matplotlib

# その他のライブラリ
from scipy import signal, stats
from scipy.signal import savgol_filter
from scipy.spatial.distance import euclidean
from tslearn.metrics import dtw_path
from fastdtw import fastdtw

# %%
#Apple Watchのモーションデータの読み込み
a_yuuma_motion_data = mr.process_apple_watch_csv("datasets/yuuma/20240604/yuuma_motion.csv")
b_sakamoto_motion_data = mr.process_apple_watch_csv("datasets/sakamoto/20240604/sakamoto_motion.csv")
c_watabe_motion_data = mr.process_apple_watch_csv("datasets/watabe/20240605/watabe_motion.csv")
d_nakazawa_motion_data = mr.process_apple_watch_csv("datasets/nakazawa/20240606/nakazawa_motion.csv")
e_okede_motion_data = mr.process_apple_watch_csv("datasets/okeda/20240607/okeda_motion.csv")
# a_yuuma_motion_data = mr.process_apple_watch_csv("/content/drive/MyDrive/datasets/yuuma/20240604/yuuma_motion.csv")
# b_sakamoto_motion_data = mr.process_apple_watch_csv("/content/drive/MyDrive/datasets/sakamoto/20240604/sakamoto_motion.csv")
# c_watabe_motion_data = mr.process_apple_watch_csv("/content/drive/MyDrive/datasets/watabe/20240605/watabe_motion.csv")
# d_nakazawa_motion_data = mr.process_apple_watch_csv("/content/drive/MyDrive/datasets/nakazawa/20240606/nakazawa_motion.csv")
# e_okeda_motion_data = mr.process_apple_watch_csv("/content/drive/MyDrive/datasets/okeda/20240607/okeda_motion.csv")

# %%
#Tobiiのモーションデータの読み込み
a_yuuma_eye_data = mr.process_tobii_csv("datasets/yuuma/20240604/yuuma_eye.csv")
b_sakamoto_eye_data = mr.process_tobii_csv("datasets/sakamoto/20240604/sakamoto_eye.csv")
c_watabe_eye_data = mr.process_tobii_csv("datasets/watabe/20240605/watabe_eye.csv")
d_nakazawa_eye_data = mr.process_tobii_csv("datasets/nakazawa/20240606/nakazawa_eye.csv")
e_okeda_eye_data = mr.process_tobii_csv("datasets/okeda/20240607/okeda_eye.csv")
# a_yuuma_eye_data = mr.process_tobii_csv("/content/drive/MyDrive/datasets/yuuma/20240604/yuuma_eye.csv")
# b_sakamoto_eye_data = mr.process_tobii_csv("/content/drive/MyDrive/datasets/sakamoto/20240604/sakamoto_eye.csv")
# c_watabe_eye_data = mr.process_tobii_csv("/content/drive/MyDrive/datasets/watabe/20240605/watabe_eye.csv")
# d_nakazawa_eye_data = mr.process_tobii_csv("/content/drive/MyDrive/datasets/nakazawa/20240606/nakazawa_eye.csv")
# e_okeda_eye_data = mr.process_tobii_csv("/content/drive/MyDrive/datasets/okeda/20240607/okeda_eye.csv")
# Out:
# /Users/hinase/CodeChord/MasterResearch/MasterResearchFunction.py:109: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   eye_data = pd.read_csv(file_path, header=0)
# /Users/hinase/CodeChord/MasterResearch/MasterResearchFunction.py:109: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   eye_data = pd.read_csv(file_path, header=0)
# /Users/hinase/CodeChord/MasterResearch/MasterResearchFunction.py:109: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   eye_data = pd.read_csv(file_path, header=0)
# /Users/hinase/CodeChord/MasterResearch/MasterResearchFunction.py:109: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   eye_data = pd.read_csv(file_path, header=0)

# %%
#a_yuumaくんの教師データ読み込み
a_yuuma_check = mr.process_all_apple_watch_csv_in_directory("datasets/yuuma/train_gesture/check")
a_yuuma_circle = mr.process_all_apple_watch_csv_in_directory("datasets/yuuma/train_gesture/circle")
a_yuuma_cross = mr.process_all_apple_watch_csv_in_directory("datasets/yuuma/train_gesture/cross(new)")
a_yuuma_tri = mr.process_all_apple_watch_csv_in_directory("datasets/yuuma/train_gesture/tri")
# a_yuuma_check = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/yuuma/train_gesture/check")
# a_yuuma_circle = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/yuuma/train_gesture/circle")
# a_yuuma_cross = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/yuuma/train_gesture/cross(new)")
# a_yuuma_tri = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/yuuma/train_gesture/tri")

# %%
#b_sakamotoくんの教師データ読み込み
b_sakamoto_check = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(old)/check")
b_sakamoto_circle = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(old)/circle")
b_sakamoto_cross = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(old)/cross")
b_sakamoto_tri = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(old)/tri")
# b_sakamoto_check = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(old)/check")
# b_sakamoto_circle = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(old)/circle")
# b_sakamoto_cross = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(old)/cross")
# b_sakamoto_tri = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(old)/tri")

# %%
#b_sakamotoくんの教師データ読み込み
b_sakamoto_check = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/check")
b_sakamoto_circle = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/circle")
b_sakamoto_cross = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/cross")
b_sakamoto_tri = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/tri")
# b_sakamoto_check = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(new)/check")
# b_sakamoto_circle = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(new)/circle")
# b_sakamoto_cross = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(new)/cross")
# b_sakamoto_tri = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/sakamoto/train_gesture(new)/tri")

# %%
#c_watabeくんの教師データ読み込み
c_watabe_check = mr.process_all_apple_watch_csv_in_directory("datasets/watabe/train_gesture/check")
c_watabe_circle = mr.process_all_apple_watch_csv_in_directory("datasets/watabe/train_gesture/circle")
c_watabe_cross = mr.process_all_apple_watch_csv_in_directory("datasets/watabe/train_gesture/cross")
c_watabe_tri = mr.process_all_apple_watch_csv_in_directory("datasets/watabe/train_gesture/tri")
# c_watabe_check = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/watabe/train_gesture/check")
# c_watabe_circle = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/watabe/train_gesture/circle")
# c_watabe_cross = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/watabe/train_gesture/cross")
# c_watabe_tri = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/watabe/train_gesture/tri")

# %%
#d_nakazawaくんの教師データ読み込み
d_nakazawa_check = mr.process_all_apple_watch_csv_in_directory("datasets/nakazawa/train_gesture/check")
d_nakazawa_circle = mr.process_all_apple_watch_csv_in_directory("datasets/nakazawa/train_gesture/circle")
d_nakazawa_cross = mr.process_all_apple_watch_csv_in_directory("datasets/nakazawa/train_gesture/cross")
d_nakazawa_tri = mr.process_all_apple_watch_csv_in_directory("datasets/nakazawa/train_gesture/tri")
# d_nakazawa_check = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/nakazawa/train_gesture/check")
# d_nakazawa_circle = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/nakazawa/train_gesture/circle")
# d_nakazawa_cross = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/nakazawa/train_gesture/cross")
# d_nakazawa_tri = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/nakazawa/train_gesture/tri")

# %%
#e_okedaくんの教師データ読み込み
e_okeda_check = mr.process_all_apple_watch_csv_in_directory("datasets/okeda/train_gesture/check")
e_okeda_circle = mr.process_all_apple_watch_csv_in_directory("datasets/okeda/train_gesture/circle")
e_okeda_cross = mr.process_all_apple_watch_csv_in_directory("datasets/okeda/train_gesture/cross")
e_okeda_tri = mr.process_all_apple_watch_csv_in_directory("datasets/okeda/train_gesture/tri")
# e_okeda_check = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/okeda/train_gesture/check")
# e_okeda_circle = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/okeda/train_gesture/circle")
# e_okeda_cross = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/okeda/train_gesture/cross")
# e_okeda_tri = mr.process_all_apple_watch_csv_in_directory("/content/drive/MyDrive/datasets/okeda/train_gesture/tri")

# %%
circle_start_time = pd.Timestamp('2024-06-04 18:34:55')
circle_end_time = pd.Timestamp('2024-06-04 18:34:59')
cross_start_time = pd.Timestamp('2024-06-04 18:45:10')
cross_end_time = pd.Timestamp('2024-06-04 18:45:14')
tri_start_time = pd.Timestamp('2024-06-04 19:06:48')
tri_end_time = pd.Timestamp('2024-06-04 19:06:52')
check_start_time = pd.Timestamp('2024-06-04 19:21:52')
check_end_time = pd.Timestamp('2024-06-04 19:21:55')

gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]

data = b_sakamoto_motion_data[
    (b_sakamoto_motion_data['Timestamp'] >= (circle_start_time - pd.Timedelta(seconds=5))) &
    (b_sakamoto_motion_data['Timestamp'] <= (circle_end_time + pd.Timedelta(seconds=5)))
]

# %%
Th = 170

# %%
#b_sakamotoくんの教師データ読み込み
b_sakamoto_check = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/check")
b_sakamoto_circle = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/circle")
b_sakamoto_cross = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/cross")
b_sakamoto_tri = mr.process_all_apple_watch_csv_in_directory("datasets/sakamoto/train_gesture(new)/tri")

# %%
segx, segy, segz = [], [], []
for i in range(len(b_sakamoto_circle)):
    segx.append(mr.spring_ogawa(data['GyroX'].reset_index(drop = True), b_sakamoto_circle[i]['GyroX'], Th))
    segy.append(mr.spring_ogawa(data['GyroY'].reset_index(drop = True), b_sakamoto_circle[i]['GyroY'], Th))
    segz.append(mr.spring_ogawa(data['GyroZ'].reset_index(drop = True), b_sakamoto_circle[i]['GyroZ'], Th))

# %%
segx

# %%
segy

# %%
segz

# %%
def filter_seg_by_elapsed_time(seg, motion_data, min_time, max_time):
    filtered_seg = []
    for segment in seg:  # 直接セグメントをイテレート
        temp = []
        for (l, d_min, t_s, t_e) in segment:
            start_time = motion_data['Timestamp'][t_s]
            end_time = motion_data['Timestamp'][t_e]
            elapsed_time = (end_time - start_time).total_seconds()
            if min_time < elapsed_time < max_time:
                temp.append((t_s, t_e))
        filtered_seg.append(temp)  # フィルタリング後にデータが存在しなくても空リストを追加
    return filtered_seg

# %%
#  pickleファイルを読み込む
with open('/Users/hinase/Downloads/a_yuuma_acc_circle_segments4.15.pkl', 'rb') as f:
    data = pickle.load(f)

segx = data['a_yuuma_circle_segx']
segy = data['a_yuuma_circle_segy']
segz = data['a_yuuma_circle_segz']

# %%
segz
# Out:
# [[[179, 3.331740643829107, 41, 124],
#   [494, 4.138343393802643, 378, 424],
#   [1154, 3.5640496313571925, 1102, 1135],
#   [1268, 2.8830760717391963, 1189, 1235],
#   [1304, 2.6072068214416504, 1256, 1283],
#   [1352, 2.3597309589385977, 1309, 1333],
#   [1411, 2.809387624263763, 1358, 1398],
#   [1502, 3.90857583284378, 1454, 1490],
#   [1864, 4.103756129741669, 1831, 1853],
#   [1916, 3.496222995221615, 1860, 1896],
#   [1946, 3.458319589495659, 1913, 1925],
#   [2000, 3.8530298583209497, 1967, 1987],
#   [2046, 3.5343059152364726, 1995, 2027],
#   [2157, 3.571919500827789, 2090, 2130],
#   [2301, 3.2815454453229895, 2232, 2263],
#   [2392, 3.460653912276028, 2341, 2375],
#   [2555, 2.684428632259368, 2447, 2516],
#   [2677, 3.706606283783912, 2630, 2667],
#   [2747, 3.3822410106658944, 2690, 2736],
#   [3490, 3.9826970063149933, 3264, 3388],
#   [3955, 3.6515463292598724, 3877, 3923],
#   [4609, 3.514313727617264, 4449, 4527],
#   [4835, 4.115013480186462, 4796, 4823],
#   [4911, 2.121286988258362, 4826, 4853],
#   [5023, 3.3747271299362187, 4958, 5000],
#   [5125, 3.5943556427955627, 5014, 5077],
#   [6023, 2.829579949378966, 5940, 5990],
#   [6347, 3.9968703985214225, 6328, 6338],
#   [6471, 3.897638738155365, 6418, 6442],
#   [6569, 2.8369066584855323, 6521, 6541],
#   [6724, 2.9380396604537964, 6687, 6715],
#   [6980, 3.2425580769777285, 6907, 6947],
#   [8137, 2.593418013304472, 8062, 8120],
#   [8386, 3.769820902496575, 8282, 8359],
#   [8723, 2.581556931138037, 8614, 8677],
#   [8933, 2.4169962406158434, 8759, 8872],
#   [9072, 3.1920086741447444, 9012, 9051],
#   [9190, 3.9863943457603446, 9144, 9176],
#   [9603, 2.519263148307799, 9455, 9525],
#   [9709, 3.6039599180221558, 9643, 9680],
#   [9940, 2.2153350114822383, 9809, 9912],
#   [10103, 3.3289962336421013, 10027, 10063],
#   [10603, 3.539195299148559, 10518, 10575],
#   [10804, 2.7907359600067143, 10729, 10783],
#   [10875, 2.745656788349152, 10797, 10852],
#   [12152, 3.710123002529144, 12074, 12130],
#   [12600, 3.291297852993009, 12523, 12584],
#   [12714, 3.953617036342621, 12603, 12682],
#   [12839, 3.494604125618934, 12715, 12784],
#   [13084, 3.907355727627873, 12958, 13060],
#   [13286, 2.819653294980525, 13196, 13272],
#   [13605, 3.0306765511631957, 13452, 13557],
#   [13731, 2.7562490105628963, 13663, 13710],
#   [13848, 3.477511405944824, 13755, 13817],
#   [14038, 2.654476270079612, 13966, 14013],
#   [14109, 2.6102516651153564, 14028, 14082],
#   [38811, 3.955254770815372, 38641, 38745],
#   [38901, 3.232275903224944, 38814, 38871],
#   [39041, 3.2811846509575835, 38929, 39001],
#   [39426, 3.141248881816864, 39275, 39357],
#   [39560, 3.4533763490617266, 39394, 39510],
#   [39726, 2.7580762412399045, 39626, 39699],
#   [40416, 2.991646103560923, 40296, 40380],
#   [41342, 3.294245401397346, 41236, 41310],
#   [41442, 3.35061015188694, 41327, 41379],
#   [45155, 3.811779201030731, 44923, 44961],
#   [47492, 3.82630854845047, 47355, 47426],
#   [52873, 4.064644813537597, 52816, 52843],
#   [54164, 4.1035295724868766, 54089, 54132],
#   [60457, 3.857995092868804, 60268, 60313],
#   [61015, 3.6339029371738425, 60932, 60965],
#   [65676, 4.063411891460418, 65619, 65640],
#   [68419, 3.648594260215759, 68316, 68348],
#   [71514, 3.570709764957428, 71450, 71478],
#   [72826, 3.697382528334856, 72705, 72789],
#   [73184, 3.906508862972259, 73097, 73120],
#   [73282, 3.487261887639759, 73146, 73220],
#   [73401, 3.2644415851682407, 73249, 73365],
#   [73497, 3.7487834617495537, 73392, 73467],
#   [98158, 4.1353661715984344, 97963, 97999],
#   [117766, 3.9544438123703, 117607, 117673],
#   [118451, 3.5557442903518663, 118254, 118372],
#   [118874, 4.137746756430714, 118598, 118671],
#   [124072, 3.9802549481391907, 123980, 124046],
#   [134688, 3.585417062044143, 134617, 134652],
#   [167780, 4.00596410036087, 167717, 167758],
#   [171780, 3.3962308764457707, 171720, 171754],
#   [174862, 4.021105706691741, 174773, 174811],
#   [175668, 3.894309118390083, 175506, 175537]]]

# %%
filtered_segx = filter_seg_by_elapsed_time(segx, a_yuuma_motion_data, 2, 4)
filtered_segy = filter_seg_by_elapsed_time(segy, a_yuuma_motion_data, 2, 4)
filtered_segz = filter_seg_by_elapsed_time(segz, a_yuuma_motion_data, 2, 4)

# %%
filtered_segz
# Out:
# [[(3264, 3388),
#   (8759, 8872),
#   (9809, 9912),
#   (12958, 13060),
#   (13452, 13557),
#   (14904, 15012),
#   (15263, 15418),
#   (15528, 15640),
#   (16395, 16503),
#   (20881, 20991),
#   (21865, 22032),
#   (22269, 22381),
#   (23650, 23770),
#   (25061, 25169),
#   (25967, 26091),
#   (26546, 26651),
#   (28286, 28394),
#   (28717, 28822),
#   (29444, 29560),
#   (31993, 32094),
#   (34745, 34921),
#   (34962, 35065),
#   (35922, 36023),
#   (36299, 36403),
#   (37339, 37453),
#   (37492, 37601),
#   (39387, 39511),
#   (73248, 73364),
#   (117652, 117766)],
#  [(8759, 8871),
#   (9806, 9912),
#   (13451, 13557),
#   (14903, 15012),
#   (18742, 18846),
#   (20877, 20991),
#   (21393, 21498),
#   (21803, 21908),
#   (23649, 23770),
#   (25060, 25171),
#   (25964, 26082),
#   (26544, 26651),
#   (27466, 27574),
#   (28283, 28394),
#   (28717, 28823),
#   (28876, 28998),
#   (29441, 29560),
#   (31034, 31145),
#   (33861, 33966),
#   (34961, 35065),
#   (35190, 35292),
#   (35921, 36037),
#   (36358, 36485),
#   (37339, 37453),
#   (37488, 37620),
#   (39392, 39511),
#   (73247, 73364)],
#  [(8759, 8871),
#   (9808, 9914),
#   (12958, 13061),
#   (14905, 15011),
#   (15263, 15385),
#   (15527, 15630),
#   (23649, 23770),
#   (24878, 24997),
#   (25964, 26082),
#   (26548, 26651),
#   (28285, 28387),
#   (29450, 29560),
#   (30175, 30292),
#   (34963, 35065),
#   (35921, 36034),
#   (36299, 36402),
#   (37339, 37446),
#   (37491, 37601),
#   (40752, 40887),
#   (65714, 65868),
#   (73249, 73364),
#   (123699, 123884)],
#  [(8759, 8872),
#   (9806, 9914),
#   (13452, 13557),
#   (14905, 15011),
#   (15114, 15221),
#   (15263, 15385),
#   (15526, 15648),
#   (15900, 16010),
#   (16393, 16503),
#   (16536, 16639),
#   (16670, 16771),
#   (20878, 20991),
#   (21392, 21500),
#   (21806, 21908),
#   (23491, 23611),
#   (23649, 23770),
#   (24877, 24997),
#   (25061, 25172),
#   (25402, 25517),
#   (25964, 26091),
#   (26548, 26651),
#   (27468, 27574),
#   (28285, 28394),
#   (28717, 28822),
#   (29441, 29560),
#   (31034, 31145),
#   (33477, 33615),
#   (33927, 34037),
#   (34963, 35065),
#   (35534, 35651),
#   (35986, 36090),
#   (37009, 37124),
#   (37339, 37453),
#   (37490, 37620),
#   (38640, 38745),
#   (39393, 39511),
#   (50464, 50571),
#   (65729, 65885),
#   (72683, 72790),
#   (73249, 73364),
#   (117651, 117766)],
#  [(8828, 8945),
#   (14905, 15011),
#   (15263, 15386),
#   (15527, 15631),
#   (16394, 16497),
#   (21393, 21495),
#   (21865, 22014),
#   (22194, 22310),
#   (23649, 23769),
#   (25964, 26081),
#   (26543, 26649),
#   (28285, 28388),
#   (28717, 28819),
#   (28876, 28995),
#   (29441, 29568),
#   (30175, 30303),
#   (31034, 31145),
#   (31628, 31730),
#   (33927, 34037),
#   (34963, 35065),
#   (35921, 36036),
#   (36299, 36402),
#   (37010, 37124),
#   (37491, 37620),
#   (38641, 38745),
#   (39394, 39510),
#   (73249, 73365),
#   (118254, 118372)]]

# %%
segx = filter_seg_by_elapsed_time(segx, data.reset_index(drop = True), 2, 4)
segy = filter_seg_by_elapsed_time(segy, data.reset_index(drop = True), 2, 4)
segz = filter_seg_by_elapsed_time(segz, data.reset_index(drop = True), 2, 4)

# %%
segx

# %%
segy

# %%
segz

# %%
def combine_and_find_overlapping_segments_alpha(segx, segy, segz):
    # Combine all segments
    all_segments = []
    for seg in [segx, segy, segz]:
        for (t_s, t_e) in seg:
            all_segments.append((t_s, t_e))

    # Sort segments
    all_segments.sort()

    # Find overlapping segments
    overlap_ranges = []
    current_overlap = None
    current_count = 0

    for start, end in all_segments:
        if current_overlap is None:
            current_overlap = (start, end)
            current_count = 1
        else:
            current_start, current_end = current_overlap
            if start <= current_end:
                current_overlap = (current_start, max(current_end, end))
                current_count += 1
            else:
                if current_count >= 2:
                    overlap_ranges.append(current_overlap)
                current_overlap = (start, end)
                current_count = 1

    if current_count >= 2:
        overlap_ranges.append(current_overlap)

    return overlap_ranges

# %%
# 各教師データの結果ごとにオーバーラップを検出
overlap = []
for i in range(len(filtered_segx)):
    overlap.append(combine_and_find_overlapping_segments_alpha(filtered_segx[i], filtered_segy[i], filtered_segz[i]))

# %%
segx

# %%
segy

# %%
segz

# %%
overlap
# Out:
# [[(29444, 29682)],
#  [],
#  [(9808, 9935), (23632, 23770), (29450, 29682)],
#  [(24806, 24997),
#   (25363, 25517),
#   (25890, 26091),
#   (29441, 29682),
#   (38640, 38832),
#   (117632, 117766)],
#  [(23632, 23769), (29441, 29682), (38641, 38832)]]

# %%
filtered_overlap = mr.filter_overlap_by_elapsed_time(overlap, a_yuuma_motion_data, 2, 4)

# %%
filtered_overlap
# Out:
# [[(9808, 9935), (23632, 23770)],
#  [(24806, 24997), (25363, 25517), (38640, 38832), (117632, 117766)],
#  [(23632, 23769), (38641, 38832)]]

# %%
data['Timestamp'].reset_index(drop = True)[520]

# %%
a_yuuma_motion_data['Timestamp'][23632]
# Out:
# Timestamp('2024-06-04 16:05:08.295982848')

# %%
a_yuuma_combine_overlap = mr.combine_all_overlaps(filtered_overlap)

# %%
a_yuuma_combine_overlap
# Out:
# [(9808, 9935),
#  (23632, 23770),
#  (24806, 24997),
#  (25363, 25517),
#  (38640, 38832),
#  (117632, 117766)]

# %%
a_yuuma_results =  mr.extract_timestamp_from_overlap(a_yuuma_motion_data, a_yuuma_combine_overlap)

# %%
a_yuuma_results
# Out:
# [[Timestamp('2024-06-04 16:00:31.973660928'),
#   Timestamp('2024-06-04 16:00:34.512285952')],
#  [Timestamp('2024-06-04 16:05:08.295982848'),
#   Timestamp('2024-06-04 16:05:11.054481920')],
#  [Timestamp('2024-06-04 16:05:31.762555136'),
#   Timestamp('2024-06-04 16:05:35.580347904')],
#  [Timestamp('2024-06-04 16:05:42.896267776'),
#   Timestamp('2024-06-04 16:05:45.974630144')],
#  [Timestamp('2024-06-04 16:10:08.277480960'),
#   Timestamp('2024-06-04 16:10:12.115343104')],
#  [Timestamp('2024-06-04 16:46:30.329495040'),
#   Timestamp('2024-06-04 16:46:33.008007168')]]

# %%
a_yuuma_filtered_results = mr.filter_segments_by_time_length(a_yuuma_results, 2, 4)

# %%
a_yuuma_extracted_eye_data = mr.extract_eye_data_within_intervals(a_yuuma_filtered_results, a_yuuma_eye_data)

# %%
a_yuuma_filtered_extracted_eye_data, a_yuuma_filtered_filtered_results = filter_by_std_gaze(a_yuuma_extracted_eye_data, a_yuuma_filtered_results, 20)
# Out:
# 20.197152747937444 0.047566093699622516 0.04647790804788797
# 28.980274791533372 0.060176911092773115 0.042423431139652044
# 37.13098854623689 0.05964751808281649 0.1206253286067144
# 37.62660385940788 0.04583107958536722 0.09941188444420056
# 38.44841733956389 0.06272030126746692 0.09193915701102873
# 41.62333612604336 0.03637718024289735 0.1022603569784091

# %%
from itertools import combinations

# 元のリスト
pairs = [(102, 214), (105, 213), (296, 402), (296, 404), (298, 430), (299, 402)]

# 組同士の差が一定以下の場合に同じグループとみなす閾値
threshold = 10

# ペアをグループ化する関数
def group_pairs(pairs, threshold):
    grouped = []
    used = [False] * len(pairs)

    for i in range(len(pairs)):
        if not used[i]:
            group = [pairs[i]]
            used[i] = True
            for j in range(i + 1, len(pairs)):
                if not used[j] and all(abs(x - y) <= threshold for x, y in zip(pairs[i], pairs[j])):
                    group.append(pairs[j])
                    used[j] = True
            grouped.append(group)
    return grouped

# グループ化されたペアのリスト
grouped_pairs = group_pairs(pairs, threshold)

# グループごとに代表するペアを選択（ここでは最初のペアを選択）
result = [group[0] for group in grouped_pairs]

print(result)

# %%
# Combine all segments from multiple lists into one list
combined_segments = []
for segments in filtered_overlap:
    combined_segments.extend(segments)

# Sort combined segments
combined_segments.sort()

# %%
combined_segments

# %%
def combine_all_overlaps(overlap):
    # Combine all segments from multiple lists into one list
    combined_segments = []
    for segments in overlap:
        combined_segments.extend(segments)

    # Sort combined segments
    combined_segments.sort()

    # Find and merge overlapping segments
    final_segments = []
    current_overlap = None

    for start, end in combined_segments:
        if current_overlap is None:
            current_overlap = (start, end)
        else:
            current_start, current_end = current_overlap
            if start <= current_end:
                # Check if the current segment is completely within the previous segment
                if end <= current_end:
                    continue
                else:
                    # Extend the current overlap segment
                    current_overlap = (current_start, end)
            else:
                # If there is no overlap, add the current overlap to final segments
                final_segments.append(current_overlap)
                current_overlap = (start, end)

    if current_overlap is not None:
        final_segments.append(current_overlap)

    return final_segments

# 使用例
filtered_overlap = [
    [(163, 340), (367, 522)],
    [(98, 244), (255, 449)],
    [(0, 114), (369, 517)],
    [(98, 244), (255, 448)]
]

final_overlap = combine_all_overlaps(filtered_overlap)
print(final_overlap)

# %%
print(final_overlap)

# %%
filtered_overlap

# %%
combine_all_overlapss(filtered_overlap)

# %%
final_overlap

# %%
data['Timestamp'].reset_index(drop = True)[448]

# %%
data['Timestamp'].reset_index(drop = True)[400]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# データの準備
diff_x = a_yuuma_eye_data['Gaze point X'].diff()
diff_y = a_yuuma_eye_data['Gaze point Y'].diff()
gaze_distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

pupil_diameter_change_l = a_yuuma_eye_data['Pupil diameter left'].diff().abs()  # 瞳孔径の変化量
pupil_diameter_change_r = a_yuuma_eye_data['Pupil diameter right'].diff().abs()  # 瞳孔径の変化量

# ジェスチャの設定
gestures = [
    (pd.Timestamp('2024-06-04 16:00:31'), pd.Timestamp('2024-06-04 16:00:34'), "Circle"),
    (pd.Timestamp('2024-06-04 16:10:55'), pd.Timestamp('2024-06-04 16:10:58'), "Cross"),
    (pd.Timestamp('2024-06-04 16:31:37'), pd.Timestamp('2024-06-04 16:31:40'), "Triangle"),
    (pd.Timestamp('2024-06-04 16:46:43'), pd.Timestamp('2024-06-04 16:46:46'), "Check")
]

# 分割数の設定
split_size = len(a_yuuma_eye_data) // 5

for i in range(5):
    start_idx = i * split_size
    end_idx = (i + 1) * split_size if i < 2 else len(a_yuuma_eye_data)

    # プロット用データの抽出
    subset_data = a_yuuma_eye_data.iloc[start_idx:end_idx]
    subset_gaze_distance = gaze_distance.iloc[start_idx:end_idx]
    subset_pupil_diameter_change_l = pupil_diameter_change_l.iloc[start_idx:end_idx]
    subset_pupil_diameter_change_r = pupil_diameter_change_r.iloc[start_idx:end_idx]

    # プロット
    fig, ax1 = plt.subplots(figsize=(147, 14))

    # 視線の移動距離のプロット
    color = 'tab:blue'
    ax1.set_xlabel('Timestamp')
    ax1.set_ylabel('Gaze Movement Distance (pixels)', color=color)
    ax1.plot(subset_data['Timestamp'], subset_gaze_distance, label='Gaze Movement Distance', color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    # 瞳孔径の変化量のプロット（左目）
    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel('Pupil Diameter Change Left', color=color)
    ax2.plot(subset_data['Timestamp'], subset_pupil_diameter_change_l, label='Pupil Diameter Change Left', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    # 瞳孔径の変化量のプロット（右目）
    ax3 = ax1.twinx()
    color = 'tab:green'
    ax3.set_ylabel('Pupil Diameter Change Right', color=color)
    ax3.plot(subset_data['Timestamp'], subset_pupil_diameter_change_r, label='Pupil Diameter Change Right', color=color)
    ax3.tick_params(axis='y', labelcolor=color)

    # ジェスチャ区間をハイライト
    for start_time, end_time, label in gestures:
        if start_time >= subset_data['Timestamp'].min() and end_time <= subset_data['Timestamp'].max():
            ax1.axvspan(start_time, end_time, color='yellow', alpha=0.3, label=f'{label} Gesture')

    # タイトルと凡例
    fig.suptitle('Gaze Movement Distance and Pupil Diameter Change with Gestures Highlighted')
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')

    # グリッドとレイアウト
    fig.tight_layout()
    plt.grid(True)
    plt.xticks(rotation=45)

    # プロットの保存
    plt.savefig(f'gaze_plot_part_{i + 1}.png', format='png', bbox_inches='tight')

    # プロットの表示
    plt.show()

# %%
a_yuuma_eye_data.columns

# %%
circle_start_time = pd.Timestamp('2024-06-04 16:00:31')
circle_end_time = pd.Timestamp('2024-06-04 16:00:34')
cross_start_time = pd.Timestamp('2024-06-04 16:10:55')
cross_end_time = pd.Timestamp('2024-06-04 16:10:58')
tri_start_time = pd.Timestamp('2024-06-04 16:31:37')
tri_end_time = pd.Timestamp('2024-06-04 16:31:40')
check_start_time = pd.Timestamp('2024-06-04 16:46:43')
check_end_time = pd.Timestamp('2024-06-04 16:46:46')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# データ準備
eye_data = d_nakazawa_eye_data.copy()

# タイムスタンプをインデックスに設定
eye_data.set_index('Timestamp', inplace=True)

# 特徴量リスト
features = [
    'Gaze point X', 'Gaze point Y', 'Gaze point 3D X', 'Gaze point 3D Y', 'Gaze point 3D Z',
    'Gaze direction left X', 'Gaze direction left Y', 'Gaze direction left Z',
    'Gaze direction right X', 'Gaze direction right Y', 'Gaze direction right Z',
    'Pupil position left X', 'Pupil position left Y', 'Pupil position left Z',
    'Pupil position right X', 'Pupil position right Y', 'Pupil position right Z',
    'Pupil diameter left', 'Pupil diameter right', 'Fixation point X', 'Fixation point Y'
]

# 特徴量エンジニアリング
# 視線の移動距離の計算
eye_data['Gaze Movement Distance'] = np.sqrt(eye_data['Gaze point X'].diff()**2 + eye_data['Gaze point Y'].diff()**2)

# 瞳孔径の変化量の計算
eye_data['Pupil Diameter Change Left'] = eye_data['Pupil diameter left'].diff().abs()
eye_data['Pupil Diameter Change Right'] = eye_data['Pupil diameter right'].diff().abs()

# 追加する特徴量
features += ['Gaze Movement Distance', 'Pupil Diameter Change Left', 'Pupil Diameter Change Right']

# ラベル付け
def label_gesture_intervals(data, gestures):
    data['Gesture'] = 0
    for start_time, end_time, _ in gestures:
        data.loc[(data.index >= start_time) & (data.index <= end_time), 'Gesture'] = 1
    return data

# ジェスチャ区間をラベル付け
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]

eye_data = label_gesture_intervals(eye_data, gestures)

# 特徴量とラベルを分割
X = eye_data[features].fillna(0)
y = eye_data['Gesture']

# データ分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# モデルの学習
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# 予測
y_pred = clf.predict(X_test)

# 評価
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# 特徴量の重要性をプロット
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(14, 8))
plt.title("Feature Importances")
plt.bar(range(X.shape[1]), importances[indices], align="center")
plt.xticks(range(X.shape[1]), [features[i] for i in indices], rotation=45)
plt.xlim([-1, X.shape[1]])
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ジェスチャの区間
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]

# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))
fig.subplots_adjust(hspace=0.3)

for i, (start_time, end_time, label) in enumerate(gestures):
    data = a_yuuma_eye_data[
        (a_yuuma_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (a_yuuma_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    axes[i].plot(data['Timestamp'], data['Pupil diameter left'], label='Pupil Diameter Left')
    axes[i].plot(data['Timestamp'], data['Pupil diameter right'], label='Pupil Diameter Right')
    # axes[i].plot(data['Timestamp'], data['Fixation point X'], label='Fixation Point X')
    # axes[i].plot(data['Timestamp'], data['Fixation point Y'], label='Fixation Point Y')

    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Interval')
    axes[i].set_title(f'{label} Gesture')
    axes[i].set_xlabel('Timestamp')
    axes[i].set_ylabel('Value')
    axes[i].legend(loc='upper right')
    axes[i].grid(True)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

plt.show()

# %%
# 統計量の計算
stats = []

for start_time, end_time, label in gestures:
    gesture_data = a_yuuma_eye_data[(a_yuuma_eye_data['Timestamp'] >= start_time) & (a_yuuma_eye_data['Timestamp'] <= end_time)]
    non_gesture_data = a_yuuma_eye_data[~((a_yuuma_eye_data['Timestamp'] >= start_time) & (a_yuuma_eye_data['Timestamp'] <= end_time))]

    stats.append({
        'Gesture': label,
        'Pupil Diameter Left (Gesture Mean)': gesture_data['Pupil diameter left'].mean(),
        'Pupil Diameter Right (Gesture Mean)': gesture_data['Pupil diameter right'].mean(),
        'Fixation Point X (Gesture Mean)': gesture_data['Fixation point X'].mean(),
        'Fixation Point Y (Gesture Mean)': gesture_data['Fixation point Y'].mean(),
        'Pupil Diameter Left (Non-Gesture Mean)': non_gesture_data['Pupil diameter left'].mean(),
        'Pupil Diameter Right (Non-Gesture Mean)': non_gesture_data['Pupil diameter right'].mean(),
        'Fixation Point X (Non-Gesture Mean)': non_gesture_data['Fixation point X'].mean(),
        'Fixation Point Y (Non-Gesture Mean)': non_gesture_data['Fixation point Y'].mean(),
    })

stats_df = pd.DataFrame(stats)
stats_df

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# データの準備（例としてa_yuuma_eye_dataを使用）
diff_x = a_yuuma_eye_data['Gaze point X'].diff()
diff_y = a_yuuma_eye_data['Gaze point Y'].diff()
gaze_distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

pupil_diameter_change_l = a_yuuma_eye_data['Pupil diameter left'].diff().abs()  # 瞳孔径の変化量
pupil_diameter_change_r = a_yuuma_eye_data['Pupil diameter right'].diff().abs()  # 瞳孔径の変化量

# ジェスチャの設定
gestures = [
    (pd.Timestamp('2024-06-04 16:00:31'), pd.Timestamp('2024-06-04 16:00:34'), "Circle"),
    (pd.Timestamp('2024-06-04 16:10:55'), pd.Timestamp('2024-06-04 16:10:58'), "Cross"),
    (pd.Timestamp('2024-06-04 16:31:37'), pd.Timestamp('2024-06-04 16:31:40'), "Triangle"),
    (pd.Timestamp('2024-06-04 16:46:43'), pd.Timestamp('2024-06-04 16:46:46'), "Check")
]

# ジェスチャ区間と非ジェスチャ区間を分割
gesture_data = []
non_gesture_data = []

for start_time, end_time, label in gestures:
    gesture_data.append(a_yuuma_eye_data[(a_yuuma_eye_data['Timestamp'] >= start_time) & (a_yuuma_eye_data['Timestamp'] <= end_time)])
    non_gesture_data.append(a_yuuma_eye_data[(a_yuuma_eye_data['Timestamp'] < start_time) | (a_yuuma_eye_data['Timestamp'] > end_time)])

gesture_data = pd.concat(gesture_data)
non_gesture_data = pd.concat(non_gesture_data)

# 特徴量の抽出
gesture_gaze_distance = gesture_data['Gaze point X'].diff().pow(2).add(gesture_data['Gaze point Y'].diff().pow(2)).pow(0.5)
non_gesture_gaze_distance = non_gesture_data['Gaze point X'].diff().pow(2).add(non_gesture_data['Gaze point Y'].diff().pow(2)).pow(0.5)

gesture_pupil_diameter_change_l = gesture_data['Pupil diameter left'].diff().abs()
non_gesture_pupil_diameter_change_l = non_gesture_data['Pupil diameter left'].diff().abs()

gesture_pupil_diameter_change_r = gesture_data['Pupil diameter right'].diff().abs()
non_gesture_pupil_diameter_change_r = non_gesture_data['Pupil diameter right'].diff().abs()

# t検定の実行
t_test_results = {
    'Gaze Movement Distance': stats.ttest_ind(gesture_gaze_distance.dropna(), non_gesture_gaze_distance.dropna()),
    'Pupil Diameter Change Left': stats.ttest_ind(gesture_pupil_diameter_change_l.dropna(), non_gesture_pupil_diameter_change_l.dropna()),
    'Pupil Diameter Change Right': stats.ttest_ind(gesture_pupil_diameter_change_r.dropna(), non_gesture_pupil_diameter_change_r.dropna())
}

# 結果を表示
for feature, result in t_test_results.items():
    print(f'{feature}: t-statistic = {result.statistic}, p-value = {result.pvalue}')

# プロット
fig, axes = plt.subplots(3, 1, figsize=(12, 18))

axes[0].hist(gesture_gaze_distance.dropna(), bins=50, alpha=0.7, label='Gesture')
axes[0].hist(non_gesture_gaze_distance.dropna(), bins=50, alpha=0.7, label='Non-Gesture')
axes[0].set_title('Gaze Movement Distance')
axes[0].legend()

axes[1].hist(gesture_pupil_diameter_change_l.dropna(), bins=50, alpha=0.7, label='Gesture')
axes[1].hist(non_gesture_pupil_diameter_change_l.dropna(), bins=50, alpha=0.7, label='Non-Gesture')
axes[1].set_title('Pupil Diameter Change Left')
axes[1].legend()

axes[2].hist(gesture_pupil_diameter_change_r.dropna(), bins=50, alpha=0.7, label='Gesture')
axes[2].hist(non_gesture_pupil_diameter_change_r.dropna(), bins=50, alpha=0.7, label='Non-Gesture')
axes[2].set_title('Pupil Diameter Change Right')
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
# 閾値などの設定
Th1 = 0.8504605035143463
Th2 = 1.880403851491724
Th3 = 1.6337734943781184
min_time = 1.5
max_time = 4
#Type = 'acc'
Type = 'sgacc'
#Type = 'gyro'

# %%
# 標準偏差を計算するスライディングウィンドウのサイズ
window_size = 50

# プロット
plt.figure(figsize=(72, 7))
ex_data = b_sakamoto_eye_data[(b_sakamoto_eye_data['Timestamp'] >= (circle_start_time - pd.Timedelta(seconds=20))) &
        (b_sakamoto_eye_data['Timestamp'] <= (circle_end_time + pd.Timedelta(seconds=20)))]

diff_x = ex_data['Gaze point X'].interpolate(method='linear').diff()
diff_y = ex_data['Gaze point Y'].interpolate(method='linear').diff()
distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離
aaa = distance.rolling(window=window_size, center=True).std()

# Gaze point Xの標準偏差の推移をプロット
# plt.plot(std_dev_gaze_x, label='Std Dev of Gaze Point X')

# Gaze point Yの標準偏差の推移をプロット
# plt.plot(std_dev_gaze_y, label='Std Dev of Gaze Point Y')
plt.plot(ex_data['Timestamp'], aaa, label='Std Dev of Gaze Point X')
plt.xlabel('Timestamp')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation of Gaze Points with 150-Data Sliding Window')
plt.axvspan(circle_start_time, circle_end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# プロットの表示
plt.show()

# %%
a_yuuma_circle_overlap = mr.overlap_from_three_segments(a_yuuma_circle_segx, a_yuuma_circle_segy, a_yuuma_circle_segz)
a_yuuma_filtered_overlap = mr.filter_overlap_by_elapsed_time(a_yuuma_circle_overlap, a_yuuma_motion_data, min_time, max_time)
a_yuuma_combine_overlap = mr.combine_all_overlaps(a_yuuma_filtered_overlap)
a_yuuma_results =  mr.extract_timestamp_from_overlap(a_yuuma_motion_data, a_yuuma_combine_overlap)
a_yuuma_filtered_results = mr.filter_segments_by_time_length(a_yuuma_results, min_time, max_time)
len(a_yuuma_filtered_results)

# %%
min_time = 1
max_time = 4

# %%
#  pickleファイルを読み込む
with open('/Users/hinase/Downloads/gyro_tri_segments25.pkl', 'rb') as f:
    data = pickle.load(f)

# 変数を復元する
a_yuuma_tri_segx = data['a_yuuma_tri_segx']
a_yuuma_tri_segy = data['a_yuuma_tri_segy']
a_yuuma_tri_segz = data['a_yuuma_tri_segz']
b_sakamoto_tri_segx = data['b_sakamoto_tri_segx']
b_sakamoto_tri_segy = data['b_sakamoto_tri_segy']
b_sakamoto_tri_segz = data['b_sakamoto_tri_segz']
c_watabe_tri_segx = data['c_watabe_tri_segx']
c_watabe_tri_segy = data['c_watabe_tri_segy']
c_watabe_tri_segz = data['c_watabe_tri_segz']
d_nakazawa_tri_segx = data['d_nakazawa_tri_segx']
d_nakazawa_tri_segy = data['d_nakazawa_tri_segy']
d_nakazawa_tri_segz = data['d_nakazawa_tri_segz']
a_yuuma_tri_overlap = mr.overlap_from_three_segments(a_yuuma_tri_segx, a_yuuma_tri_segy, a_yuuma_tri_segz)
b_sakamoto_tri_overlap = mr.overlap_from_three_segments(b_sakamoto_tri_segx, b_sakamoto_tri_segy, b_sakamoto_tri_segz)
c_watabe_tri_overlap = mr.overlap_from_three_segments(c_watabe_tri_segx, c_watabe_tri_segy, c_watabe_tri_segz)
d_nakazawa_tri_overlap = mr.overlap_from_three_segments(d_nakazawa_tri_segx, d_nakazawa_tri_segy, d_nakazawa_tri_segz)
# 経過時間のフィルタリングを適用
a_yuuma_filtered_overlap = mr.filter_overlap_by_elapsed_time(a_yuuma_tri_overlap, a_yuuma_motion_data, min_time, max_time)
b_sakamoto_filtered_overlap = mr.filter_overlap_by_elapsed_time(b_sakamoto_tri_overlap, b_sakamoto_motion_data, min_time, max_time)
c_watabe_filtered_overlap = mr.filter_overlap_by_elapsed_time(c_watabe_tri_overlap, c_watabe_motion_data, min_time, max_time)
d_nakazawa_filtered_overlap = mr.filter_overlap_by_elapsed_time(d_nakazawa_tri_overlap, d_nakazawa_motion_data, min_time, max_time)
# オーバーラップを統合
a_yuuma_combine_overlap = mr.combine_all_overlaps(a_yuuma_filtered_overlap)
b_sakamoto_combine_overlap = mr.combine_all_overlaps(b_sakamoto_filtered_overlap)
c_watabe_combine_overlap = mr.combine_all_overlaps(c_watabe_filtered_overlap)
d_nakazawa_combine_overlap = mr.combine_all_overlaps(d_nakazawa_filtered_overlap)
# 統合された組からタイムスタンプの組を抽出する
a_yuuma_results =  mr.extract_timestamp_from_overlap(a_yuuma_motion_data, a_yuuma_combine_overlap)
b_sakamoto_results =  mr.extract_timestamp_from_overlap(b_sakamoto_motion_data, b_sakamoto_combine_overlap)
c_watabe_results =  mr.extract_timestamp_from_overlap(c_watabe_motion_data, c_watabe_combine_overlap)
d_nakazawa_results =  mr.extract_timestamp_from_overlap(d_nakazawa_motion_data, d_nakazawa_combine_overlap)
# 各組の時間の長さが2秒以下と5秒以上のものを弾く
a_yuuma_filtered_results = mr.filter_segments_by_time_length(a_yuuma_results, min_time, max_time)
b_sakamoto_filtered_results = mr.filter_segments_by_time_length(b_sakamoto_results, min_time, max_time)
c_watabe_filtered_results = mr.filter_segments_by_time_length(c_watabe_results, min_time, max_time)
d_nakazawa_filtered_results = mr.filter_segments_by_time_length(d_nakazawa_results, min_time, max_time)

# %%
c_watabe_filtered_results

# %%
# 2列目の値が9000から10000の範囲だけを抜き出す
filtered_c_watabe_tri_segx = filter_segments_by_second_column(c_watabe_tri_segx, 72800, 73300)

# 結果を表示
for i, segment in enumerate(filtered_c_watabe_tri_segx):
    print(f"Segment {i+1}:")
    for row in segment:
        print(row)

# %%
c_watabe_motion_data['Timestamp'][72800]

# %%
# カスタム距離関数
def absolute_difference(a, b):
    return np.abs(a - b)

# %%
# 特徴量リスト
features = ['EuclideanNorm', 'EuclideanNormGyro']

# 距離を保存するためのリストを作成
distance_list = []

# カスタム距離関数
def absolute_difference(a, b):
    return np.abs(a - b)

# DTW距離の計算
for feature in features:
    for i in range(len(a_yuuma_circle)):
        for j in range(i+1, len(a_yuuma_circle)):
            # i番目とj番目のデータのDTW距離を計算
            series_i = a_yuuma_circle[i][feature].values.flatten()
            series_j = a_yuuma_circle[j][feature].values.flatten()
            distance, _ = fastdtw(series_i, series_j, dist=absolute_difference)

            # 結果をリストに追加
            distance_list.append({
                'Feature': feature,
                'i': i,
                'j': j,
                'DTW_Distance': distance
            })

# リストをデータフレームに変換
distance_df = pd.DataFrame(distance_list)

# 表を表示
print(distance_df)

# %%
distance_df[distance_df['Feature']=='EuclideanNorm']['DTW_Distance'].max()

# %%
a = np.sqrt(a_yuuma_circle[i]['AccelerationX']**2 + a_yuuma_circle[i]['AccelerationY']**2 + a_yuuma_circle[i]['AccelerationZ']**2)
b = np.sqrt(a_yuuma_circle[i]['GyroX']**2 + a_yuuma_circle[i]['GyroY']**2 + a_yuuma_circle[i]['GyroZ']**2)

# %%
for i in range(len(a_yuuma_circle)):
  a = np.sqrt(a_yuuma_circle[i]['AccelerationX']**2 + a_yuuma_circle[i]['AccelerationY']**2 + a_yuuma_circle[i]['AccelerationZ']**2)
  b = np.sqrt(a_yuuma_circle[i]['GyroX']**2 + a_yuuma_circle[i]['GyroY']**2 + a_yuuma_circle[i]['GyroZ']**2)
  plt.figure()
  plt.plot(a)
  plt.plot(b)

# %%
distance_df[distance_df['Feature']=='SG_AccelerationZ']['DTW_Distance'].median()

# %%
distance_df[distance_df['Feature']=='SG_AccelerationZ']['DTW_Distance'].min()

# %%
# 標準偏差を計算するスライディングウィンドウのサイズ
window_size = 150

# %%
#  pickleファイルを読み込む
with open('/Users/hinase/Downloads/gyro_cross_segments50.pkl', 'rb') as f:
    data = pickle.load(f)

# 変数を復元する
a_yuuma_cross_segx = data['a_yuuma_cross_segx']
a_yuuma_cross_segy = data['a_yuuma_cross_segy']
a_yuuma_cross_segz = data['a_yuuma_cross_segz']
b_sakamoto_cross_segx = data['b_sakamoto_cross_segx']
b_sakamoto_cross_segy = data['b_sakamoto_cross_segy']
b_sakamoto_cross_segz = data['b_sakamoto_cross_segz']
c_watabe_cross_segx = data['c_watabe_cross_segx']
c_watabe_cross_segy = data['c_watabe_cross_segy']
c_watabe_cross_segz = data['c_watabe_cross_segz']
d_nakazawa_cross_segx = data['d_nakazawa_cross_segx']
d_nakazawa_cross_segy = data['d_nakazawa_cross_segy']
d_nakazawa_cross_segz = data['d_nakazawa_cross_segz']
a_yuuma_cross_overlap = mr.overlap_from_three_segments(a_yuuma_cross_segx, a_yuuma_cross_segy, a_yuuma_cross_segz)
b_sakamoto_cross_overlap = mr.overlap_from_three_segments(b_sakamoto_cross_segx, b_sakamoto_cross_segy, b_sakamoto_cross_segz)
c_watabe_cross_overlap = mr.overlap_from_three_segments(c_watabe_cross_segx, c_watabe_cross_segy, c_watabe_cross_segz)
d_nakazawa_cross_overlap = mr.overlap_from_three_segments(d_nakazawa_cross_segx, d_nakazawa_cross_segy, d_nakazawa_cross_segz)
# 経過時間のフィルタリングを適用
a_yuuma_filtered_overlap = mr.filter_overlap_by_elapsed_time(a_yuuma_cross_overlap, a_yuuma_motion_data, min_time, max_time)
b_sakamoto_filtered_overlap = mr.filter_overlap_by_elapsed_time(b_sakamoto_cross_overlap, b_sakamoto_motion_data, min_time, max_time)
c_watabe_filtered_overlap = mr.filter_overlap_by_elapsed_time(c_watabe_cross_overlap, c_watabe_motion_data, min_time, max_time)
d_nakazawa_filtered_overlap = mr.filter_overlap_by_elapsed_time(d_nakazawa_cross_overlap, d_nakazawa_motion_data, min_time, max_time)
# オーバーラップを統合
a_yuuma_combine_overlap = mr.combine_all_overlaps(a_yuuma_filtered_overlap)
b_sakamoto_combine_overlap = mr.combine_all_overlaps(b_sakamoto_filtered_overlap)
c_watabe_combine_overlap = mr.combine_all_overlaps(c_watabe_filtered_overlap)
d_nakazawa_combine_overlap = mr.combine_all_overlaps(d_nakazawa_filtered_overlap)
# 統合された組からタイムスタンプの組を抽出する
a_yuuma_results =  mr.extract_timestamp_from_overlap(a_yuuma_motion_data, a_yuuma_combine_overlap)
b_sakamoto_results =  mr.extract_timestamp_from_overlap(b_sakamoto_motion_data, b_sakamoto_combine_overlap)
c_watabe_results =  mr.extract_timestamp_from_overlap(c_watabe_motion_data, c_watabe_combine_overlap)
d_nakazawa_results =  mr.extract_timestamp_from_overlap(d_nakazawa_motion_data, d_nakazawa_combine_overlap)
# 各組の時間の長さが2秒以下と5秒以上のものを弾く
a_yuuma_filtered_results = mr.filter_segments_by_time_length(a_yuuma_results, min_time, max_time)
b_sakamoto_filtered_results = mr.filter_segments_by_time_length(b_sakamoto_results, min_time, max_time)
c_watabe_filtered_results = mr.filter_segments_by_time_length(c_watabe_results, min_time, max_time)
d_nakazawa_filtered_results = mr.filter_segments_by_time_length(d_nakazawa_results, min_time, max_time)

# %%
# 2列目の値が9000から10000の範囲だけを抜き出す
filtered_a_yuuma_circle_segy = filter_segments_by_second_column(a_yuuma_circle_segy, 9600, 10000)

# 結果を表示
for i, segment in enumerate(filtered_a_yuuma_circle_segy):
    print(f"Segment {i+1}:")
    for row in segment:
        print(row)

# %%
a_yuuma_motion_data['Timestamp'][9808]

# %%
a_yuuma_motion_data['Timestamp'][9808]

# %%
#  pickleファイルを読み込む
with open('/Users/hinase/Downloads/a_yuuma_gyro_circle_segments20.pkl', 'rb') as f:
    data = pickle.load(f)

a_yuuma_circle_segx = data['a_yuuma_circle_segx']
a_yuuma_circle_segy = data['a_yuuma_circle_segy']
a_yuuma_circle_segz = data['a_yuuma_circle_segz']

# %%
min_time = 2
max_time = 4

# %%
a_yuuma_circle_overlap = mr.overlap_from_three_segments(a_yuuma_circle_segx, a_yuuma_circle_segy, a_yuuma_circle_segz)
a_yuuma_filtered_overlap = mr.filter_overlap_by_elapsed_time(a_yuuma_circle_overlap, a_yuuma_motion_data, min_time, max_time)
a_yuuma_combine_overlap = mr.combine_all_overlaps(a_yuuma_filtered_overlap)
a_yuuma_results =  mr.extract_timestamp_from_overlap(a_yuuma_motion_data, a_yuuma_combine_overlap)
a_yuuma_filtered_results = mr.filter_segments_by_time_length(a_yuuma_results, min_time, max_time)
len(a_yuuma_filtered_results)

# %%
a_yuuma_extracted_eye_data = mr.extract_eye_data_within_intervals(a_yuuma_filtered_results, a_yuuma_eye_data)
a_yuuma_filtered_extracted_eye_data, a_yuuma_filtered_filtered_results = filter_by_std_gaze(a_yuuma_extracted_eye_data, a_yuuma_filtered_results, 20)

# %%
a_yuuma_extracted_eye_data

# %%
c_watabe_filtered_filtered_results

# %%
len(c_watabe_filtered_filtered_results)

# %%
c_watabe_motion_data['Timestamp'][40650]

# %%
# 閾値などの設定
Th = 40
min_time = 2
max_time = 4
#Type = 'acc'
Type = 'gyro'

# %%
# 保存する変数を辞書にまとめる
data = {
    'b_sakamoto_cross_segx': b_sakamoto_cross_segx,
    'b_sakamoto_cross_segy': b_sakamoto_cross_segy,
    'b_sakamoto_cross_segz': b_sakamoto_cross_segz
}
# 変数をpickleファイルに保存
with open('b_sakamoto_gyro_cross_segments40.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
b_sakamoto_cross_overlap = mr.overlap_from_three_segments(b_sakamoto_cross_segx, b_sakamoto_cross_segy, b_sakamoto_cross_segz)
b_sakamoto_filtered_overlap = mr.filter_overlap_by_elapsed_time(b_sakamoto_cross_overlap, b_sakamoto_motion_data, min_time, max_time)
b_sakamoto_combine_overlap = mr.combine_all_overlaps(b_sakamoto_filtered_overlap)
b_sakamoto_results =  mr.extract_timestamp_from_overlap(b_sakamoto_motion_data, b_sakamoto_combine_overlap)
b_sakamoto_filtered_results = mr.filter_segments_by_time_length(b_sakamoto_results, min_time, max_time)
len(b_sakamoto_filtered_results)

# %%
b_sakamoto_cross_segx

# %%
len(b_sakamoto_filtered_results)

# %%
b_sakamoto_extracted_eye_data = mr.extract_eye_data_within_intervals(b_sakamoto_filtered_results, b_sakamoto_eye_data)
b_sakamoto_filtered_extracted_eye_data, b_sakamoto_filtered_filtered_results = filter_by_std_gaze(b_sakamoto_extracted_eye_data, b_sakamoto_filtered_results, 43)

# %%
len(b_sakamoto_filtered_filtered_results)

# %%
d_nakazawa_cross_segx, d_nakazawa_cross_segy, d_nakazawa_cross_segz = mr.three_axis_spring_ogawa(d_nakazawa_motion_data, d_nakazawa_cross, Th, Type)

# %%
d_nakazawa_cross_overlap = mr.overlap_from_three_segments(d_nakazawa_cross_segx, d_nakazawa_cross_segy, d_nakazawa_cross_segz)
d_nakazawa_filtered_overlap = mr.filter_overlap_by_elapsed_time(d_nakazawa_cross_overlap, d_nakazawa_motion_data, min_time, max_time)
d_nakazawa_combine_overlap = mr.combine_all_overlaps(d_nakazawa_filtered_overlap)
d_nakazawa_results =  mr.extract_timestamp_from_overlap(d_nakazawa_motion_data, d_nakazawa_combine_overlap)
d_nakazawa_filtered_results = mr.filter_segments_by_time_length(d_nakazawa_results, min_time, max_time)
len(d_nakazawa_filtered_results)

# %%
min_time = 1.75

max_time = 4

# %%
d_nakazawa_extracted_eye_data = mr.extract_eye_data_within_intervals(d_nakazawa_filtered_results, d_nakazawa_eye_data)
d_nakazawa_filtered_extracted_eye_data, d_nakazawa_filtered_filtered_results = filter_by_std_gaze(d_nakazawa_extracted_eye_data, d_nakazawa_filtered_results, 42)

# %%
len(d_nakazawa_filtered_filtered_results)

# %%
# 2列目の値が9000から10000の範囲だけを抜き出す
filtered_d_nakazawa_cross_segx = filter_segments_by_second_column(d_nakazawa_cross_segx, 41300, 41800)

# 結果を表示
for i, segment in enumerate(filtered_d_nakazawa_cross_segx):
    print(f"Segment {i+1}:")
    for row in segment:
        print(row)

# %%
d_nakazawa_motion_data['Timestamp'][41564]

# %%
#  pickleファイルを読み込む
with open('/Users/hinase/Downloads/acc_circle_segments5.pkl', 'rb') as f:
    data = pickle.load(f)
c_watabe_circle_segx = data['c_watabe_circle_segx']
c_watabe_circle_segy = data['c_watabe_circle_segy']
c_watabe_circle_segz = data['c_watabe_circle_segz']

# %%
c_watabe_circle_overlap = mr.overlap_from_three_segments(c_watabe_circle_segx, c_watabe_circle_segy, c_watabe_circle_segz)
c_watabe_filtered_overlap = mr.filter_overlap_by_elapsed_time(c_watabe_circle_overlap, c_watabe_motion_data, min_time, max_time)
c_watabe_combine_overlap = mr.combine_all_overlaps(c_watabe_filtered_overlap)
c_watabe_results =  mr.extract_timestamp_from_overlap(c_watabe_motion_data, c_watabe_combine_overlap)
c_watabe_filtered_results = mr.filter_segments_by_time_length(c_watabe_results, min_time, max_time)

# %%
len(c_watabe_filtered_results)

# %%
b_sakamoto_extracted_eye_data = mr.extract_eye_data_within_intervals(b_sakamoto_filtered_results, b_sakamoto_eye_data)

# %%
b_sakamoto_filtered_extracted_eye_data, b_sakamoto_filtered_filtered_results = filter_by_std_gaze(b_sakamoto_extracted_eye_data, b_sakamoto_filtered_results, 36)

# %%
len(b_sakamoto_filtered_filtered_results)

# %%
circle_start_time = pd.Timestamp('2024-06-06 13:44:14')
circle_end_time = pd.Timestamp('2024-06-06 13:44:17')
cross_start_time = pd.Timestamp('2024-06-06 13:54:44')
cross_end_time = pd.Timestamp('2024-06-06 13:54:47')
tri_start_time = pd.Timestamp('2024-06-06 14:14:51')
tri_end_time = pd.Timestamp('2024-06-06 14:14:55')
check_start_time = pd.Timestamp('2024-6-06 14:30:22')
check_end_time = pd.Timestamp('2024-06-06 14:30:25')

# %%
len(d_nakazawa_filtered_results)

# %%
# 区間リストの定義
intervals = [
    (d_nakazawa_motion_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, d_nakazawa_motion_data['Timestamp'].max(), 'Desk work')
]

# 結果をカウントする辞書
interval_counts = {label: 0 for _, _, label in intervals}
a = 0

# 各フィルタされた結果の区間をカウント
for start, end in d_nakazawa_filtered_results:
    for interval_start, interval_end, label in intervals:
        # 許容誤差を設定
        tolerance = pd.Timedelta(seconds=2.5)

        # 誤差を許容した範囲での判定
        if ((interval_start - tolerance) <= start <= (interval_end + tolerance)) or ((interval_start - tolerance) <= end <= (interval_end + tolerance)):
            interval_counts[label] += 1
            a += 1
            break

# 結果を表示
print(interval_counts)
print(a)

# %%
circle_start_time = pd.Timestamp('2024-06-06 13:44:14')
circle_end_time = pd.Timestamp('2024-06-06 13:44:17')
cross_start_time = pd.Timestamp('2024-06-06 13:54:44')
cross_end_time = pd.Timestamp('2024-06-06 13:54:47')
tri_start_time = pd.Timestamp('2024-06-06 14:14:51')
tri_end_time = pd.Timestamp('2024-06-06 14:14:55')
check_start_time = pd.Timestamp('2024-6-06 14:30:22')
check_end_time = pd.Timestamp('2024-06-06 14:30:25')

# %%
min_time = 2
max_time = 4

# %%
Th = 10
Type = 'acc'

# %%
d_nakazawa_circle_segx, d_nakazawa_circle_segy, d_nakazawa_circle_segz = mr.three_axis_spring_ogawa(d_nakazawa_motion_data, d_nakazawa_circle, 20, 'gyro')

# %%
# 保存する変数を辞書にまとめる
data = {
    'd_nakazawa_circle_segx': d_nakazawa_circle_segx,
    'd_nakazawa_circle_segy': d_nakazawa_circle_segy,
    'd_nakazawa_circle_segz': d_nakazawa_circle_segz
}
# 変数をpickleファイルに保存
with open('d_nakazawa_gyro_circle_segments20.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
min_time, max_time = 1.75, 4

# %%
d_nakazawa_cross_overlap = mr.overlap_from_three_segments(d_nakazawa_cross_segx, d_nakazawa_cross_segy, d_nakazawa_cross_segz)
d_nakazawa_filtered_overlap = mr.filter_overlap_by_elapsed_time(d_nakazawa_cross_overlap, d_nakazawa_motion_data, min_time, max_time)
d_nakazawa_combine_overlap = mr.combine_all_overlaps(d_nakazawa_filtered_overlap)
d_nakazawa_results =  mr.extract_timestamp_from_overlap(d_nakazawa_motion_data, d_nakazawa_combine_overlap)
d_nakazawa_filtered_results = mr.filter_segments_by_time_length(d_nakazawa_results, min_time, max_time)
len(d_nakazawa_filtered_results)

# %%
d_nakazawa_extracted_eye_data = mr.extract_eye_data_within_intervals(d_nakazawa_filtered_results, d_nakazawa_eye_data)
d_nakazawa_filtered_extracted_eye_data, d_nakazawa_filtered_filtered_results = filter_by_std_gaze(d_nakazawa_extracted_eye_data, d_nakazawa_filtered_results, 19)

# %%
# 2列目の値が9000から10000の範囲だけを抜き出す
filtered_a_yuuma_cross_segz = filter_segments_by_second_column(a_yuuma_cross_segz, 9830, 10050)

# 結果を表示
for i, segment in enumerate(filtered_a_yuuma_cross_segz):
    print(f"Segment {i+1}:")
    for row in segment:
        print(row)

# %%
d_nakazawa_motion_data['Timestamp'][9934]

# %%
#  pickleファイルを読み込む
with open('/Users/hinase/Downloads/gyro_circle_segments50.pkl', 'rb') as f:
    data = pickle.load(f)

# 変数を復元する
a_yuuma_circle_segx = data['a_yuuma_circle_segx']
a_yuuma_circle_segy = data['a_yuuma_circle_segy']
a_yuuma_circle_segz = data['a_yuuma_circle_segz']
b_sakamoto_circle_segx = data['b_sakamoto_circle_segx']
b_sakamoto_circle_segy = data['b_sakamoto_circle_segy']
b_sakamoto_circle_segz = data['b_sakamoto_circle_segz']
c_watabe_circle_segx = data['c_watabe_circle_segx']
c_watabe_circle_segy = data['c_watabe_circle_segy']
c_watabe_circle_segz = data['c_watabe_circle_segz']
d_nakazawa_circle_segx = data['d_nakazawa_circle_segx']
d_nakazawa_circle_segy = data['d_nakazawa_circle_segy']
d_nakazawa_circle_segz = data['d_nakazawa_circle_segz']
a_yuuma_circle_overlap = mr.overlap_from_three_segments(a_yuuma_circle_segx, a_yuuma_circle_segy, a_yuuma_circle_segz)
b_sakamoto_circle_overlap = mr.overlap_from_three_segments(b_sakamoto_circle_segx, b_sakamoto_circle_segy, b_sakamoto_circle_segz)
c_watabe_circle_overlap = mr.overlap_from_three_segments(c_watabe_circle_segx, c_watabe_circle_segy, c_watabe_circle_segz)
d_nakazawa_circle_overlap = mr.overlap_from_three_segments(d_nakazawa_circle_segx, d_nakazawa_circle_segy, d_nakazawa_circle_segz)
# 経過時間のフィルタリングを適用
a_yuuma_filtered_overlap = mr.filter_overlap_by_elapsed_time(a_yuuma_circle_overlap, a_yuuma_motion_data, min_time, max_time)
b_sakamoto_filtered_overlap = mr.filter_overlap_by_elapsed_time(b_sakamoto_circle_overlap, b_sakamoto_motion_data, min_time, max_time)
c_watabe_filtered_overlap = mr.filter_overlap_by_elapsed_time(c_watabe_circle_overlap, c_watabe_motion_data, min_time, max_time)
d_nakazawa_filtered_overlap = mr.filter_overlap_by_elapsed_time(d_nakazawa_circle_overlap, d_nakazawa_motion_data, min_time, max_time)

# %%
d_nakazawa_circle_overlap = mr.overlap_from_three_segments(d_nakazawa_circle_segx, d_nakazawa_circle_segy, d_nakazawa_circle_segz)
d_nakazawa_filtered_overlap = mr.filter_overlap_by_elapsed_time(d_nakazawa_circle_overlap, d_nakazawa_motion_data, min_time, max_time)
d_nakazawa_combine_overlap = mr.combine_all_overlaps(d_nakazawa_filtered_overlap)
d_nakazawa_results =  mr.extract_timestamp_from_overlap(d_nakazawa_motion_data, d_nakazawa_combine_overlap)
d_nakazawa_filtered_results = mr.filter_segments_by_time_length(d_nakazawa_results, min_time, max_time)

# %%
len(d_nakazawa_filtered_results)

# %%
d_nakazawa_filtered_results

# %%
d_nakazawa_extracted_eye_data = mr.extract_eye_data_within_intervals(d_nakazawa_filtered_results, d_nakazawa_eye_data)
d_nakazawa_filtered_extracted_eye_data, d_nakazawa_filtered_filtered_results = filter_by_std_gaze(d_nakazawa_extracted_eye_data, d_nakazawa_filtered_results, 19)

# %%
d_nakazawa_filtered_filtered_results

# %%
c_watabe_motion_data['Timestamp'][10025]

# %%
def filter_by_std_gaze(extracted_eye_data, filtered_results, threshold):
    filtered_extracted_eye_data = []
    filtered_filtered_results = []

    for i in range(len(extracted_eye_data)):
        diff_x = extracted_eye_data[i]['Gaze point X'].interpolate(method='linear').diff()
        diff_y = extracted_eye_data[i]['Gaze point Y'].interpolate(method='linear').diff()
        distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離
        std = distance.std()  # ユークリッド距離の分散を計算
        diff_r = extracted_eye_data[i]['Pupil diameter right'].interpolate(method='linear').diff()
        diff_l = extracted_eye_data[i]['Pupil diameter left'].interpolate(method='linear').diff()
        std_r = diff_r.std()  # ユークリッド距離の分
        std_l = diff_l.std()  # ユークリッド距離の分
        print(std, std_r, std_l)

        if std < threshold:
            filtered_extracted_eye_data.append(extracted_eye_data[i])
            filtered_filtered_results.append(filtered_results[i])

    return filtered_extracted_eye_data, filtered_filtered_results

# %%
with open('/Users/hinase/Downloads/c_watabe_acc_circle_segments3.pkl', 'rb') as f:
    data = pickle.load(f)

# 変数を復元する
c_watabe_circle_segx = data['c_watabe_circle_segx']
c_watabe_circle_segy = data['c_watabe_circle_segy']
c_watabe_circle_segz = data['c_watabe_circle_segz']

# %%
c_watabe_circle_overlap = mr.overlap_from_three_segments(c_watabe_circle_segx, c_watabe_circle_segy, c_watabe_circle_segz)
c_watabe_filtered_overlap = mr.filter_overlap_by_elapsed_time(c_watabe_circle_overlap, c_watabe_motion_data, min_time, max_time)
c_watabe_combine_overlap = mr.combine_all_overlaps(c_watabe_filtered_overlap)
c_watabe_results =  mr.extract_timestamp_from_overlap(c_watabe_motion_data, c_watabe_combine_overlap)
c_watabe_filtered_results = mr.filter_segments_by_time_length(c_watabe_results, min_time, max_time)

# %%
min_time, max_time

# %%
len(c_watabe_filtered_results)

# %%
c_watabe_extracted_eye_data = mr.extract_eye_data_within_intervals(c_watabe_filtered_results, c_watabe_eye_data)

# %%
c_watabe_filtered_extracted_eye_data, c_watabe_filtered_filtered_results = filter_by_std_gaze(c_watabe_extracted_eye_data, c_watabe_filtered_results, 30)

# %%
c_watabe_filtered_filtered_results

# %%
for i in range(len(a_yuuma_filtered_extracted_eye_data)):
  diff_x = a_yuuma_filtered_extracted_eye_data[i]['Gaze point X'].interpolate(method='linear').diff()
  diff_y = a_yuuma_filtered_extracted_eye_data[i]['Gaze point Y'].interpolate(method='linear').diff()
  distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離
  std = distance.std()  # ユークリッド距離の分
  print(std)

# %%
for i in range(len(a_yuuma_filtered_extracted_eye_data)):
  diff_r = a_yuuma_filtered_extracted_eye_data[i]['Pupil diameter right'].interpolate(method='linear').diff()
  diff_l = a_yuuma_filtered_extracted_eye_data[i]['Pupil diameter left'].interpolate(method='linear').diff()
  std_r = diff_r.std()  # ユークリッド距離の分
  std_l = diff_l.std()  # ユークリッド距離の分
  print(std_r, std_l)

# %%
std

# %%
a_yuuma_filtered_extracted_eye_data[0]

# %%
d_nakazawa_motion_data['Timestamp'][9900]

# %%
# 2列目の値が9000から10000の範囲だけ抜き出して表示する関数
def filter_segments_by_second_column(segments, lower_bound, upper_bound):
    filtered_segments = []
    for segment in segments:
        filtered_segment = [row for row in segment if lower_bound <= row[2] <= upper_bound]
        if filtered_segment:
            filtered_segments.append(filtered_segment)
    return filtered_segments

# %%
# 2列目の値が9000から10000の範囲だけを抜き出す
filtered_d_nakazawa_circle_segx = filter_segments_by_second_column(d_nakazawa_circle_segx, 9850, 10200)

# 結果を表示
for i, segment in enumerate(filtered_d_nakazawa_circle_segx):
    print(f"Segment {i+1}:")
    for row in segment:
        print(row)

# %%
d_nakazawa_motion_data['Timestamp'][9890]

# %%
min_time = 1
max_time = 5

# %%
# オーバーラップを統合
a_yuuma_combine_overlap = mr.combine_all_overlaps(a_yuuma_filtered_overlap)
b_sakamoto_combine_overlap = mr.combine_all_overlaps(b_sakamoto_filtered_overlap)
c_watabe_combine_overlap = mr.combine_all_overlaps(c_watabe_filtered_overlap)
d_nakazawa_combine_overlap = mr.combine_all_overlaps(d_nakazawa_filtered_overlap)

# %%
# 統合された組からタイムスタンプの組を抽出する
a_yuuma_results =  mr.extract_timestamp_from_overlap(a_yuuma_motion_data, a_yuuma_combine_overlap)
b_sakamoto_results =  mr.extract_timestamp_from_overlap(b_sakamoto_motion_data, b_sakamoto_combine_overlap)
c_watabe_results =  mr.extract_timestamp_from_overlap(c_watabe_motion_data, c_watabe_combine_overlap)
d_nakazawa_results =  mr.extract_timestamp_from_overlap(d_nakazawa_motion_data, d_nakazawa_combine_overlap)

# %%
# 各組の時間の長さが2秒以下と5秒以上のものを弾く
a_yuuma_filtered_results = mr.filter_segments_by_time_length(a_yuuma_results, min_time, max_time)
b_sakamoto_filtered_results = mr.filter_segments_by_time_length(b_sakamoto_results, min_time, max_time)
c_watabe_filtered_results = mr.filter_segments_by_time_length(c_watabe_results, min_time, max_time)
d_nakazawa_filtered_results = mr.filter_segments_by_time_length(d_nakazawa_results, min_time, max_time)

# %%
d_nakazawa_filtered_results

# %%
circle_start_time = pd.Timestamp('2024-06-06 13:44:14')
circle_end_time = pd.Timestamp('2024-06-06 13:44:17')
cross_start_time = pd.Timestamp('2024-06-06 13:54:44')
cross_end_time = pd.Timestamp('2024-06-06 13:54:47')
tri_start_time = pd.Timestamp('2024-06-06 14:14:51')
tri_end_time = pd.Timestamp('2024-06-06 14:14:55')
check_start_time = pd.Timestamp('2024-6-06 14:30:22')
check_end_time = pd.Timestamp('2024-06-06 14:30:25')

# %%
# 区間リストの定義
intervals = [
    (d_nakazawa_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, d_nakazawa_eye_data['Timestamp'].max(), 'Desk work')
]
# 結果をカウントする辞書
interval_counts = {label: 0 for _, _, label in intervals}
a = 0
# 各フィルタされた結果の区間をカウント
for start, end in d_nakazawa_filtered_results:
    for interval_start, interval_end, label in intervals:
        if (interval_start <= start <= interval_end) or (interval_start <= end <= interval_end):
            interval_counts[label] += 1
            a+=1
            break

# 結果を表示
print(interval_counts)
print(a)

# %%
# 結果をカウントする辞書
interval_counts = {label: 0 for _, _, label in intervals}

a = 0
# 各フィルタされた結果の区間をカウント
for start, end in d_nakazawa_filtered_results:
    for interval_start, interval_end, label in intervals:
        if (interval_start <= start <= interval_end) or (interval_start <= end <= interval_end):
            interval_counts[label] += 1
            a+=1
            break

# 結果を表示
print(interval_counts)
print(a)

# %%
# タイムスタンプの範囲内のデータを抽出
a_yuuma_extracted_eye_data = mr.extract_eye_data_within_intervals(a_yuuma_filtered_results, a_yuuma_eye_data)
b_sakamoto_extracted_eye_data = mr.extract_eye_data_within_intervals(b_sakamoto_filtered_results, b_sakamoto_eye_data)
c_watabe_extracted_eye_data = mr.extract_eye_data_within_intervals(c_watabe_filtered_results, c_watabe_eye_data)
d_nakazawa_extracted_eye_data = mr.extract_eye_data_within_intervals(d_nakazawa_filtered_results, d_nakazawa_eye_data)

# %%
# 分散を計算し、閾値を上回る区間を削除
filtered_extracted_eye_data, filtered_filtered_results = filter_by_variance(extracted_eye_data, filtered_results, Th)

# %%
circle_start_time = pd.Timestamp('2024-06-04 16:00:31')
circle_end_time = pd.Timestamp('2024-06-04 16:00:34')
cross_start_time = pd.Timestamp('2024-06-04 16:10:55')
cross_end_time = pd.Timestamp('2024-06-04 16:10:58')
tri_start_time = pd.Timestamp('2024-06-04 16:31:37')
tri_end_time = pd.Timestamp('2024-06-04 16:31:40')
check_start_time = pd.Timestamp('2024-06-04 16:46:43')
check_end_time = pd.Timestamp('2024-06-04 16:46:46')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = a_yuuma_eye_data[
        (a_yuuma_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (a_yuuma_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    # ハイライトされた区間のデータを抽出
    highlighted_data = data[(data['Timestamp'] >= start_time) & (data['Timestamp'] <= end_time)]
    highlighted_diff_x = highlighted_data['Gaze point X'].interpolate(method='linear').diff()
    highlighted_diff_y = highlighted_data['Gaze point Y'].interpolate(method='linear').diff()
    highlighted_distance = np.sqrt(highlighted_diff_x**2 + highlighted_diff_y**2)

    # 標準偏差の計算
    std_dev = highlighted_distance.std()
    std_devs.append((label, std_dev))

    axes[i].plot(data['Timestamp'], distance, label='Gaze Movement Distance')

    axes[i].grid(True)
    axes[i].set_ylabel('Gaze Movement Distance (pixels)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(0, ylimit)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    #axes[i].text(0.5, 0.85, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=20, verticalalignment='top', horizontalalignment='center')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/a_yuuma_gesture_Gaze_Movement_Distance.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (a_yuuma_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, a_yuuma_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = a_yuuma_eye_data[
        (a_yuuma_eye_data['Timestamp'] >= start_time) &
        (a_yuuma_eye_data['Timestamp'] <= end_time)
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    std_dev = distance.std()
    std_devs.append((label, std_dev))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-04 18:34:55')
circle_end_time = pd.Timestamp('2024-06-04 18:34:59')
cross_start_time = pd.Timestamp('2024-06-04 18:45:10')
cross_end_time = pd.Timestamp('2024-06-04 18:45:14')
tri_start_time = pd.Timestamp('2024-06-04 19:06:48')
tri_end_time = pd.Timestamp('2024-06-04 19:06:52')
check_start_time = pd.Timestamp('2024-06-04 19:21:52')
check_end_time = pd.Timestamp('2024-06-04 19:21:55')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = b_sakamoto_eye_data[
        (b_sakamoto_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (b_sakamoto_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    # ハイライトされた区間のデータを抽出
    highlighted_data = data[(data['Timestamp'] >= start_time) & (data['Timestamp'] <= end_time)]
    highlighted_diff_x = highlighted_data['Gaze point X'].interpolate(method='linear').diff()
    highlighted_diff_y = highlighted_data['Gaze point Y'].interpolate(method='linear').diff()
    highlighted_distance = np.sqrt(highlighted_diff_x**2 + highlighted_diff_y**2)

    # 標準偏差の計算
    std_dev = highlighted_distance.std()
    std_devs.append((label, std_dev))

    axes[i].plot(data['Timestamp'], distance, label='Gaze Movement Distance')

    axes[i].grid(True)
    axes[i].set_ylabel('Gaze Movement Distance (pixels)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(0, ylimit)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    # axes[i].text(0.99, 0.98, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top', horizontalalignment='right')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/b_sakamoto_gesture_Gaze_Movement_Distance.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (b_sakamoto_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, b_sakamoto_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = b_sakamoto_eye_data[
        (b_sakamoto_eye_data['Timestamp'] >= start_time) &
        (b_sakamoto_eye_data['Timestamp'] <= end_time)
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    std_dev = distance.std()
    std_devs.append((label, std_dev))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-05 15:36:41')
circle_end_time = pd.Timestamp('2024-06-05 15:36:44')
cross_start_time = pd.Timestamp('2024-06-05 15:46:57')
cross_end_time = pd.Timestamp('2024-06-05 15:47:00')
tri_start_time = pd.Timestamp('2024-06-05 16:03:40')
tri_end_time = pd.Timestamp('2024-06-05 16:03:44')
check_start_time = pd.Timestamp('2024-06-05 16:19:06')
check_end_time = pd.Timestamp('2024-06-05 16:19:09')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = c_watabe_eye_data[
        (c_watabe_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (c_watabe_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    # ハイライトされた区間のデータを抽出
    highlighted_data = data[(data['Timestamp'] >= start_time) & (data['Timestamp'] <= end_time)]
    highlighted_diff_x = highlighted_data['Gaze point X'].interpolate(method='linear').diff()
    highlighted_diff_y = highlighted_data['Gaze point Y'].interpolate(method='linear').diff()
    highlighted_distance = np.sqrt(highlighted_diff_x**2 + highlighted_diff_y**2)

    # 標準偏差の計算
    std_dev = highlighted_distance.std()
    std_devs.append((label, std_dev))

    axes[i].plot(data['Timestamp'], distance, label='Gaze Movement Distance')

    axes[i].grid(True)
    axes[i].set_ylabel('Gaze Movement Distance (pixels)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(0, ylimit)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    # axes[i].text(0.99, 0.98, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top', horizontalalignment='right')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/c_watabe_gesture_Gaze_Movement_Distance.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (c_watabe_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, c_watabe_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = c_watabe_eye_data[
        (c_watabe_eye_data['Timestamp'] >= start_time) &
        (c_watabe_eye_data['Timestamp'] <= end_time)
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    std_dev = distance.std()
    std_devs.append((label, std_dev))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-06 13:44:14')
circle_end_time = pd.Timestamp('2024-06-06 13:44:17')
cross_start_time = pd.Timestamp('2024-06-06 13:54:44')
cross_end_time = pd.Timestamp('2024-06-06 13:54:47')
tri_start_time = pd.Timestamp('2024-06-06 14:14:51')
tri_end_time = pd.Timestamp('2024-06-06 14:14:55')
check_start_time = pd.Timestamp('2024-6-06 14:30:22')
check_end_time = pd.Timestamp('2024-06-06 14:30:25')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = d_nakazawa_eye_data[
        (d_nakazawa_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (d_nakazawa_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    # ハイライトされた区間のデータを抽出
    highlighted_data = data[(data['Timestamp'] >= start_time) & (data['Timestamp'] <= end_time)]
    highlighted_diff_x = highlighted_data['Gaze point X'].interpolate(method='linear').diff()
    highlighted_diff_y = highlighted_data['Gaze point Y'].interpolate(method='linear').diff()
    highlighted_distance = np.sqrt(highlighted_diff_x**2 + highlighted_diff_y**2)

    # 標準偏差の計算
    std_dev = highlighted_distance.std()
    std_devs.append((label, std_dev))

    axes[i].plot(data['Timestamp'], distance, label='Gaze Movement Distance')

    axes[i].grid(True)
    axes[i].set_ylabel('Gaze Movement Distance (pixels)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(0, ylimit)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    # axes[i].text(0.99, 0.98, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top', horizontalalignment='right')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/d_nakazawa_gesture_Gaze_Movement_Distance.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (d_nakazawa_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, d_nakazawa_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = d_nakazawa_eye_data[
        (d_nakazawa_eye_data['Timestamp'] >= start_time) &
        (d_nakazawa_eye_data['Timestamp'] <= end_time)
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    std_dev = distance.std()
    std_devs.append((label, std_dev))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-07 15:33:19')
circle_end_time = pd.Timestamp('2024-06-07 15:33:22')
cross_start_time = pd.Timestamp('2024-06-07 15:43:54')
cross_end_time = pd.Timestamp('2024-06-07 15:43:57')
tri_start_time = pd.Timestamp('2024-06-07 16:01:46')
tri_end_time = pd.Timestamp('2024-06-07 16:01:49')
check_start_time = pd.Timestamp('2024-06-07 16:17:07')
check_end_time = pd.Timestamp('2024-06-07 16:17:09')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = e_okeda_eye_data[
        (e_okeda_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (e_okeda_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    # ハイライトされた区間のデータを抽出
    highlighted_data = data[(data['Timestamp'] >= start_time) & (data['Timestamp'] <= end_time)]
    highlighted_diff_x = highlighted_data['Gaze point X'].interpolate(method='linear').diff()
    highlighted_diff_y = highlighted_data['Gaze point Y'].interpolate(method='linear').diff()
    highlighted_distance = np.sqrt(highlighted_diff_x**2 + highlighted_diff_y**2)

    # 標準偏差の計算
    std_dev = highlighted_distance.std()
    std_devs.append((label, std_dev))

    axes[i].plot(data['Timestamp'], distance, label='Gaze Movement Distance')

    axes[i].grid(True)
    axes[i].set_ylabel('Gaze Movement Distance (pixels)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(0, ylimit)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    # axes[i].text(0.99, 0.98, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top', horizontalalignment='right')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/e_okeda_gesture Gaze_Movement_Distance.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (e_okeda_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, e_okeda_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = e_okeda_eye_data[
        (e_okeda_eye_data['Timestamp'] >= start_time) &
        (e_okeda_eye_data['Timestamp'] <= end_time)
    ]

    diff_x = data['Gaze point X'].interpolate(method='linear').diff()
    diff_y = data['Gaze point Y'].interpolate(method='linear').diff()
    distance = np.sqrt(diff_x**2 + diff_y**2)  # ユークリッド距離

    std_dev = distance.std()
    std_devs.append((label, std_dev))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation'])
print(std_dev_df)

# %%
ylimit = 1.0

# %%
circle_start_time = pd.Timestamp('2024-06-04 16:00:31')
circle_end_time = pd.Timestamp('2024-06-04 16:00:34')
cross_start_time = pd.Timestamp('2024-06-04 16:10:55')
cross_end_time = pd.Timestamp('2024-06-04 16:10:58')
tri_start_time = pd.Timestamp('2024-06-04 16:31:37')
tri_end_time = pd.Timestamp('2024-06-04 16:31:40')
check_start_time = pd.Timestamp('2024-06-04 16:46:43')
check_end_time = pd.Timestamp('2024-06-04 16:46:46')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = a_yuuma_eye_data[
        (a_yuuma_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (a_yuuma_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    axes[i].plot(data['Timestamp'], diff_r, label='Pupil Diameter Right')
    axes[i].plot(data['Timestamp'], diff_l, label='Pupil Diameter Left')
    axes[i].grid(True)
    axes[i].set_ylabel('Pupil Diameter Change (Millimeters)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(-1 * ylimit, ylimit)  # y軸の範囲をデータに合わせる
    #axes[i].set_ylim(3, 5)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    #axes[i].text(0.5, 0.85, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=20, verticalalignment='top', horizontalalignment='center')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/a_yuuma_gesture_Pupil_Diameter_Change.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (a_yuuma_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, a_yuuma_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = a_yuuma_eye_data[
        (a_yuuma_eye_data['Timestamp'] >= start_time) &
        (a_yuuma_eye_data['Timestamp'] <= end_time)
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    std_dev_r = diff_r.std()
    std_dev_l = diff_l.std()
    std_devs.append((label, std_dev_r, std_dev_l))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation_r', 'Standard Deviation_l'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-04 18:34:55')
circle_end_time = pd.Timestamp('2024-06-04 18:34:59')
cross_start_time = pd.Timestamp('2024-06-04 18:45:10')
cross_end_time = pd.Timestamp('2024-06-04 18:45:14')
tri_start_time = pd.Timestamp('2024-06-04 19:06:48')
tri_end_time = pd.Timestamp('2024-06-04 19:06:52')
check_start_time = pd.Timestamp('2024-06-04 19:21:52')
check_end_time = pd.Timestamp('2024-06-04 19:21:55')


# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = b_sakamoto_eye_data[
        (b_sakamoto_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (b_sakamoto_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    axes[i].plot(data['Timestamp'], diff_r, label='Pupil Diameter Right')
    axes[i].plot(data['Timestamp'], diff_l, label='Pupil Diameter Left')
    axes[i].grid(True)
    axes[i].set_ylabel('Pupil Diameter Change (Millimeters)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(-1 * ylimit, ylimit)  # y軸の範囲をデータに合わせる
    #axes[i].set_ylim(3, 5)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    #axes[i].text(0.5, 0.85, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=20, verticalalignment='top', horizontalalignment='center')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/b_sakamoto_gesture_Pupil_Diameter_Change.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (b_sakamoto_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, b_sakamoto_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = b_sakamoto_eye_data[
        (b_sakamoto_eye_data['Timestamp'] >= start_time) &
        (b_sakamoto_eye_data['Timestamp'] <= end_time)
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    std_dev_r = diff_r.std()
    std_dev_l = diff_l.std()
    std_devs.append((label, std_dev_r, std_dev_l))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation_r', 'Standard Deviation_l'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-05 15:36:41')
circle_end_time = pd.Timestamp('2024-06-05 15:36:44')
cross_start_time = pd.Timestamp('2024-06-05 15:46:57')
cross_end_time = pd.Timestamp('2024-06-05 15:47:00')
tri_start_time = pd.Timestamp('2024-06-05 16:03:40')
tri_end_time = pd.Timestamp('2024-06-05 16:03:44')
check_start_time = pd.Timestamp('2024-06-05 16:19:06')
check_end_time = pd.Timestamp('2024-06-05 16:19:09')



# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = c_watabe_eye_data[
        (c_watabe_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (c_watabe_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    axes[i].plot(data['Timestamp'], diff_r, label='Pupil Diameter Right')
    axes[i].plot(data['Timestamp'], diff_l, label='Pupil Diameter Left')
    axes[i].grid(True)
    axes[i].set_ylabel('Pupil Diameter Change (Millimeters)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(-1 * ylimit, ylimit)  # y軸の範囲をデータに合わせる
    #axes[i].set_ylim(3, 5)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    #axes[i].text(0.5, 0.85, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=20, verticalalignment='top', horizontalalignment='center')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/c_watabe_gesture_Pupil_Diameter_Change.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (c_watabe_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, c_watabe_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = c_watabe_eye_data[
        (c_watabe_eye_data['Timestamp'] >= start_time) &
        (c_watabe_eye_data['Timestamp'] <= end_time)
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    std_dev_r = diff_r.std()
    std_dev_l = diff_l.std()
    std_devs.append((label, std_dev_r, std_dev_l))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation_r', 'Standard Deviation_l'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-06 13:44:14')
circle_end_time = pd.Timestamp('2024-06-06 13:44:17')
cross_start_time = pd.Timestamp('2024-06-06 13:54:44')
cross_end_time = pd.Timestamp('2024-06-06 13:54:47')
tri_start_time = pd.Timestamp('2024-06-06 14:14:51')
tri_end_time = pd.Timestamp('2024-06-06 14:14:55')
check_start_time = pd.Timestamp('2024-6-06 14:30:22')
check_end_time = pd.Timestamp('2024-06-06 14:30:25')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = d_nakazawa_eye_data[
        (d_nakazawa_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (d_nakazawa_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    axes[i].plot(data['Timestamp'], diff_r, label='Pupil Diameter Right')
    axes[i].plot(data['Timestamp'], diff_l, label='Pupil Diameter Left')
    axes[i].grid(True)
    axes[i].set_ylabel('Pupil Diameter Change (Millimeters)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(-1 * ylimit, ylimit)  # y軸の範囲をデータに合わせる
    #axes[i].set_ylim(3, 5)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    #axes[i].text(0.5, 0.85, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=20, verticalalignment='top', horizontalalignment='center')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/d_nakazawa_gesture_Pupil_Diameter_Change.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (d_nakazawa_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, d_nakazawa_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = d_nakazawa_eye_data[
        (d_nakazawa_eye_data['Timestamp'] >= start_time) &
        (d_nakazawa_eye_data['Timestamp'] <= end_time)
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    std_dev_r = diff_r.std()
    std_dev_l = diff_l.std()
    std_devs.append((label, std_dev_r, std_dev_l))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation_r', 'Standard Deviation_l'])
print(std_dev_df)

# %%
circle_start_time = pd.Timestamp('2024-06-07 15:33:19')
circle_end_time = pd.Timestamp('2024-06-07 15:33:22')
cross_start_time = pd.Timestamp('2024-06-07 15:43:54')
cross_end_time = pd.Timestamp('2024-06-07 15:43:57')
tri_start_time = pd.Timestamp('2024-06-07 16:01:46')
tri_end_time = pd.Timestamp('2024-06-07 16:01:49')
check_start_time = pd.Timestamp('2024-06-07 16:17:07')
check_end_time = pd.Timestamp('2024-06-07 16:17:09')

# ジェスチャの設定
gestures = [
    (circle_start_time, circle_end_time, "Circle"),
    (cross_start_time, cross_end_time, "Cross"),
    (tri_start_time, tri_end_time, "Triangle"),
    (check_start_time, check_end_time, "Check")
]
# プロットの作成
fig, axes = plt.subplots(4, 1, figsize=(18, 24))  # 4行1列のサブプロットを作成
fig.subplots_adjust(hspace=0.3)  # グラフ間のスペースを広く取る
# 標準偏差を保存するリスト
std_devs = []

for i, (start_time, end_time, label) in enumerate(gestures):
    data = e_okeda_eye_data[
        (e_okeda_eye_data['Timestamp'] >= (start_time - pd.Timedelta(seconds=5))) &
        (e_okeda_eye_data['Timestamp'] <= (end_time + pd.Timedelta(seconds=5)))
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    axes[i].plot(data['Timestamp'], diff_r, label='Pupil Diameter Right')
    axes[i].plot(data['Timestamp'], diff_l, label='Pupil Diameter Left')
    axes[i].grid(True)
    axes[i].set_ylabel('Pupil Diameter Change (Millimeters)', fontsize=14)
    axes[i].set_xlabel('Timestamp (JST, H:M:S)', fontsize=14)  # 各グラフにx軸ラベルを設定
    axes[i].set_ylim(-1 * ylimit, ylimit)  # y軸の範囲をデータに合わせる
    #axes[i].set_ylim(3, 5)  # y軸の範囲をデータに合わせる
    axes[i].set_title(f'{label} Gesture', fontsize=24)
    axes[i].axvspan(start_time, end_time, color='yellow', alpha=0.3, label='Gesture Performed Segment')
    axes[i].legend(loc='upper right', fontsize=14)
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))  # Timestampフォーマット設定
    experiment_date = start_time.strftime('%Y-%m-%d')
    axes[i].text(0.01, 0.98, f'Experiment Date: {experiment_date}', transform=axes[i].transAxes, fontsize=12, verticalalignment='top')
    # 標準偏差をグラフに表示
    #axes[i].text(0.5, 0.85, f'Std Dev: {std_dev:.2f}', transform=axes[i].transAxes, fontsize=20, verticalalignment='top', horizontalalignment='center')

# プロットの保存（EPS形式）
plt.savefig("/Users/hinase/Downloads/e_okeda_gesture_Pupil_Diameter_Change.eps", format='eps', bbox_inches='tight')  # 論文用に図を保存

plt.show()  # プロットを表示
# 区間リストの定義
intervals = [
    (e_okeda_eye_data['Timestamp'].min(), circle_start_time, 'Stretch'),
    (circle_start_time, circle_end_time, 'Circle'),
    (circle_end_time, cross_start_time, 'Walking'),
    (cross_start_time, cross_end_time, 'Cross'),
    (cross_end_time, tri_start_time, 'Eating'),
    (tri_start_time, tri_end_time, 'Triangle'),
    (tri_end_time, check_start_time, 'Game'),
    (check_start_time, check_end_time, 'Check'),
    (check_end_time, e_okeda_eye_data['Timestamp'].max(), 'Desk work')
]

# 標準偏差を保存するリスト
std_devs = []

# 各区間の標準偏差を計算
for start_time, end_time, label in intervals:
    data = e_okeda_eye_data[
        (e_okeda_eye_data['Timestamp'] >= start_time) &
        (e_okeda_eye_data['Timestamp'] <= end_time)
    ]

    diff_r = data['Pupil diameter right'].interpolate(method='linear').diff()
    diff_l = data['Pupil diameter left'].interpolate(method='linear').diff()

    std_dev_r = diff_r.std()
    std_dev_l = diff_l.std()
    std_devs.append((label, std_dev_r, std_dev_l))

# 結果を出力
std_dev_df = pd.DataFrame(std_devs, columns=['Interval', 'Standard Deviation_r', 'Standard Deviation_l'])
print(std_dev_df)
